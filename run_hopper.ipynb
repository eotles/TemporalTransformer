# %%
import sqlite3
import csv
from Hopper import *

# %%
verbose = True
h = dbms(verbose=verbose)
# Out:
# DROP TABLE IF EXISTS i_ids;
#
# CREATE TABLE i_ids (
# 	i_id TEXT NOT NULL,
# 	PRIMARY KEY (i_id)
# );
#
# DROP TABLE IF EXISTS i_windows;
#
# CREATE TABLE i_windows (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL,
# 	PRIMARY KEY (i_id),
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# DROP TABLE IF EXISTS i_partitions;
#
# CREATE TABLE i_partitions (
# 	i_id TEXT NOT NULL,
# 	partition TEXT NOT NULL,
# 	PRIMARY KEY (i_id),
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# DROP TABLE IF EXISTS i_relcal;
#
# CREATE TABLE i_relcal (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL
# );

# %%
tc = table_config("characteristics_0", 
                  ["age", "sex", "eth", "bin_ldc", "job"], 
                  ["real", "bin", "ldc", "ldc", "hdc"],
                  has_times=False,
                  primary_key=True)
h.create_fvm_with_csv(tc, "data/characteristics_0.csv", delimiter=',')


_tc = table_config("samples_0", 
                  ["SBP", "DBP", "type"], 
                  ["real", "real", "ldc"], 
                  has_times=True,
                  primary_key=False)
h.create_fvm_with_csv(_tc, "data/samples_0.csv", delimiter=',')

_tc = table_config("samples_1", 
                  ["tmps", "hrs", "sbps", "rrs", "dbps", "sats", "wgts"],
                  ["real", "real", 'real', "real", "real", "real", "real"], 
                  has_times=True,
                  primary_key=False)
h.create_fvm_with_csv(_tc, "data/samples_1.csv", delimiter=',')


_tc = table_config("samples_2", 
                  ["dx"],
                  ["hdc"], 
                  has_times=True,
                  primary_key=False)
h.create_fvm_with_csv(_tc, "data/samples_2.csv", delimiter=',')


_tc = table_config("samples_3", 
                  ["outcome"],
                  ["bin"], 
                  has_times=True,
                  primary_key=False)
h.create_fvm_with_csv(_tc, "data/samples_3.csv", delimiter=',')
# Out:
# DROP TABLE IF EXISTS characteristics_0;
#
# CREATE TABLE characteristics_0 (
# 	i_id TEXT NOT NULL,
# 	age REAL NOT NULL,
# 	sex TEXT NOT NULL,
# 	eth TEXT NOT NULL,
# 	bin_ldc TEXT NOT NULL,
# 	job TEXT NOT NULL,
# 	PRIMARY KEY (i_id),
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# INSERT OR IGNORE INTO i_ids (i_id) VALUES (?);
#
# INSERT  INTO characteristics_0 (i_id, age, sex, eth, bin_ldc, job) VALUES (?, ?, ?, ?, ?, ?);
#
# CREATE INDEX i_index_characteristics_0_i_id ON characteristics_0(i_id);
#
# CREATE INDEX i_index_characteristics_0_age ON characteristics_0(age);
#
# CREATE INDEX i_index_characteristics_0_sex ON characteristics_0(sex);
#
# CREATE INDEX i_index_characteristics_0_eth ON characteristics_0(eth);
#
# CREATE INDEX i_index_characteristics_0_bin_ldc ON characteristics_0(bin_ldc);
#
# CREATE INDEX i_index_characteristics_0_job ON characteristics_0(job);
#
# 10000 rows loaded
#
# DROP TABLE IF EXISTS samples_0;
#
# CREATE TABLE samples_0 (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL,
# 	SBP REAL NOT NULL,
# 	DBP REAL NOT NULL,
# 	type TEXT NOT NULL,
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# INSERT OR IGNORE INTO i_ids (i_id) VALUES (?);
#
# INSERT  INTO samples_0 (i_id, i_st, i_et, SBP, DBP, type) VALUES (?, ?, ?, ?, ?, ?);
#
# CREATE INDEX i_index_samples_0_i_id ON samples_0(i_id);
#
# CREATE INDEX i_index_samples_0_i_st ON samples_0(i_st);
#
# CREATE INDEX i_index_samples_0_i_et ON samples_0(i_et);
#
# CREATE INDEX i_index_samples_0_SBP ON samples_0(SBP);
#
# CREATE INDEX i_index_samples_0_DBP ON samples_0(DBP);
#
# CREATE INDEX i_index_samples_0_type ON samples_0(type);
#
# 200000 rows loaded
#
# DROP TABLE IF EXISTS samples_1;
#
# CREATE TABLE samples_1 (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL,
# 	tmps REAL NOT NULL,
# 	hrs REAL NOT NULL,
# 	sbps REAL NOT NULL,
# 	rrs REAL NOT NULL,
# 	dbps REAL NOT NULL,
# 	sats REAL NOT NULL,
# 	wgts REAL NOT NULL,
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# INSERT OR IGNORE INTO i_ids (i_id) VALUES (?);
#
# INSERT  INTO samples_1 (i_id, i_st, i_et, tmps, hrs, sbps, rrs, dbps, sats, wgts) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?);
#
# CREATE INDEX i_index_samples_1_i_id ON samples_1(i_id);
#
# CREATE INDEX i_index_samples_1_i_st ON samples_1(i_st);
#
# CREATE INDEX i_index_samples_1_i_et ON samples_1(i_et);
#
# CREATE INDEX i_index_samples_1_tmps ON samples_1(tmps);
#
# CREATE INDEX i_index_samples_1_hrs ON samples_1(hrs);
#
# CREATE INDEX i_index_samples_1_sbps ON samples_1(sbps);
#
# CREATE INDEX i_index_samples_1_rrs ON samples_1(rrs);
#
# CREATE INDEX i_index_samples_1_dbps ON samples_1(dbps);
#
# CREATE INDEX i_index_samples_1_sats ON samples_1(sats);
#
# CREATE INDEX i_index_samples_1_wgts ON samples_1(wgts);
#
# 200000 rows loaded
#
# DROP TABLE IF EXISTS samples_2;
#
# CREATE TABLE samples_2 (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL,
# 	dx TEXT NOT NULL,
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# INSERT OR IGNORE INTO i_ids (i_id) VALUES (?);
#
# INSERT  INTO samples_2 (i_id, i_st, i_et, dx) VALUES (?, ?, ?, ?);
#
# CREATE INDEX i_index_samples_2_i_id ON samples_2(i_id);
#
# CREATE INDEX i_index_samples_2_i_st ON samples_2(i_st);
#
# CREATE INDEX i_index_samples_2_i_et ON samples_2(i_et);
#
# CREATE INDEX i_index_samples_2_dx ON samples_2(dx);
#
# 200000 rows loaded
#
# DROP TABLE IF EXISTS samples_3;
#
# CREATE TABLE samples_3 (
# 	i_id TEXT NOT NULL,
# 	i_st INTEGER NOT NULL,
# 	i_et INTEGER NOT NULL,
# 	outcome TEXT NOT NULL,
# 	FOREIGN KEY (i_id) REFERENCES i_ids (i_id)
# );
#
# INSERT OR IGNORE INTO i_ids (i_id) VALUES (?);
#
# INSERT  INTO samples_3 (i_id, i_st, i_et, outcome) VALUES (?, ?, ?, ?);
#
# CREATE INDEX i_index_samples_3_i_id ON samples_3(i_id);
#
# CREATE INDEX i_index_samples_3_i_st ON samples_3(i_st);
#
# CREATE INDEX i_index_samples_3_i_et ON samples_3(i_et);
#
# CREATE INDEX i_index_samples_3_outcome ON samples_3(outcome);
#
# 10000 rows loaded

# %%
#h.dew_it()

# %%
h.set_windows([['00000', 2, 5], ['00001', 3, 7]],)
# Out:
# INSERT  INTO i_windows (i_id, i_st, i_et) VALUES (?, ?, ?);
#
# gen_range_table_sql called: af=None, bf=None
# INSERT OR IGNORE INTO i_windows
# SELECT * FROM (
# 	SELECT i_id, MIN(i_st) AS i_st, MAX(i_et) AS i_et
# 	FROM (
# 	    SELECT i_id, i_st, i_et
# 		FROM samples_0
# 		UNION
# 			SELECT i_id, i_st, i_et
# 		FROM samples_1
# 		UNION
# 			SELECT i_id, i_st, i_et
# 		FROM samples_2
# 		UNION
# 			SELECT i_id, i_st, i_et
# 		FROM samples_3
#
# 	)
# 	GROUP BY i_id
# );

# %%
h.set_partitions([['00000', 'dev'], ['00001', 'dev']])
# Out:
# INSERT  INTO i_partitions (i_id, partition) VALUES (?, ?);
#
# INSERT OR IGNORE INTO i_partitions
# SELECT * FROM (
# 	SELECT i_id, CASE
# 		 WHEN r <= 0.8 THEN "train"
# 		 WHEN r <= 0.9 THEN "dev"
# 		 WHEN r <= 1.0 THEN "test"
# 		 ELSE "test"
# 	END
# 	FROM (SELECT i_id, ABS(RANDOM())/(9223372036854775807.0) AS r FROM i_ids)
# );

# %%
h.create_windows_views()
# Out:
# CREATE VIEW win_samples_0 AS
#     SELECT samples_0.i_id,
# 	MAX(samples_0.i_st, i_windows.i_st) AS i_st,
# 	MIN(samples_0.i_et, i_windows.i_et) AS i_et,
# 	SBP,
# 	DBP,
# 	type
# 	FROM (
# 	    samples_0 JOIN i_windows ON samples_0.i_id=i_windows.i_id
# 	)
# 	WHERE NOT (i_windows.i_et < samples_0.i_st OR
# 	           i_windows.i_st >= samples_0.i_et)
#
# ;
#
# CREATE VIEW win_samples_1 AS
#     SELECT samples_1.i_id,
# 	MAX(samples_1.i_st, i_windows.i_st) AS i_st,
# 	MIN(samples_1.i_et, i_windows.i_et) AS i_et,
# 	tmps,
# 	hrs,
# 	sbps,
# 	rrs,
# 	dbps,
# 	sats,
# 	wgts
# 	FROM (
# 	    samples_1 JOIN i_windows ON samples_1.i_id=i_windows.i_id
# 	)
# 	WHERE NOT (i_windows.i_et < samples_1.i_st OR
# 	           i_windows.i_st >= samples_1.i_et)
#
# ;
#
# CREATE VIEW win_samples_2 AS
#     SELECT samples_2.i_id,
# 	MAX(samples_2.i_st, i_windows.i_st) AS i_st,
# 	MIN(samples_2.i_et, i_windows.i_et) AS i_et,
# 	dx
# 	FROM (
# 	    samples_2 JOIN i_windows ON samples_2.i_id=i_windows.i_id
# 	)
# 	WHERE NOT (i_windows.i_et < samples_2.i_st OR
# 	           i_windows.i_st >= samples_2.i_et)
#
# ;
#
# CREATE VIEW win_samples_3 AS
#     SELECT samples_3.i_id,
# 	MAX(samples_3.i_st, i_windows.i_st) AS i_st,
# 	MIN(samples_3.i_et, i_windows.i_et) AS i_et,
# 	outcome
# 	FROM (
# 	    samples_3 JOIN i_windows ON samples_3.i_id=i_windows.i_id
# 	)
# 	WHERE NOT (i_windows.i_et < samples_3.i_st OR
# 	           i_windows.i_st >= samples_3.i_et)
#
# ;

# %%
h.create_partition_views_prior_to_filter()
# Out:
# SELECT DISTINCT(partition) FROM i_partitions;
#
# partitions: dev,train,test
#
# CREATE VIEW i_partitions_dev_org_characteristics_0 AS
#     SELECT * FROM characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_org_characteristics_0 AS
#     SELECT * FROM characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_org_characteristics_0 AS
#     SELECT * FROM characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_win_samples_0 AS
#     SELECT * FROM win_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_win_samples_0 AS
#     SELECT * FROM win_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_win_samples_0 AS
#     SELECT * FROM win_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_win_samples_1 AS
#     SELECT * FROM win_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_win_samples_1 AS
#     SELECT * FROM win_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_win_samples_1 AS
#     SELECT * FROM win_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_win_samples_2 AS
#     SELECT * FROM win_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_win_samples_2 AS
#     SELECT * FROM win_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_win_samples_2 AS
#     SELECT * FROM win_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_win_samples_3 AS
#     SELECT * FROM win_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_win_samples_3 AS
#     SELECT * FROM win_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_win_samples_3 AS
#     SELECT * FROM win_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;

# %%
h.fit_filter(partition='train', percentile_cutoff=0.05)
# Out:
# SELECT COUNT(*) FROM i_partitions_train_org_characteristics_0;
#
# SELECT AVG(age) AS avg,
#        SUM((age-(SELECT AVG(age) FROM i_partitions_train_org_characteristics_0))*
#        (age-(SELECT AVG(age) FROM i_partitions_train_org_characteristics_0)))
#        /(COUNT(age)-1) AS var
# FROM i_partitions_train_org_characteristics_0
# ;
#
# SELECT sex, COUNT(*) AS n
# FROM i_partitions_train_org_characteristics_0
# GROUP BY sex
# ORDER BY n DESC
# ;
#
#
# SELECT eth, COUNT(*) AS n
# FROM i_partitions_train_org_characteristics_0
# GROUP BY eth
# ORDER BY n DESC
# ;
#
#
# SELECT bin_ldc, COUNT(*) AS n
# FROM i_partitions_train_org_characteristics_0
# GROUP BY bin_ldc
# ORDER BY n DESC
# ;
#
#
# SELECT job, COUNT(*) AS n
# FROM i_partitions_train_org_characteristics_0
# GROUP BY job
# ORDER BY n DESC
# ;
#
#
# SELECT COUNT(*) FROM i_partitions_train_win_samples_0;
#
# SELECT AVG(SBP) AS avg,
#        SUM((SBP-(SELECT AVG(SBP) FROM i_partitions_train_win_samples_0))*
#        (SBP-(SELECT AVG(SBP) FROM i_partitions_train_win_samples_0)))
#        /(COUNT(SBP)-1) AS var
# FROM i_partitions_train_win_samples_0
# ;
#
# SELECT AVG(DBP) AS avg,
#        SUM((DBP-(SELECT AVG(DBP) FROM i_partitions_train_win_samples_0))*
#        (DBP-(SELECT AVG(DBP) FROM i_partitions_train_win_samples_0)))
#        /(COUNT(DBP)-1) AS var
# FROM i_partitions_train_win_samples_0
# ;
#
# SELECT type, COUNT(*) AS n
# FROM i_partitions_train_win_samples_0
# GROUP BY type
# ORDER BY n DESC
# ;
#
#
# SELECT COUNT(*) FROM i_partitions_train_win_samples_1;
#
# SELECT AVG(tmps) AS avg,
#        SUM((tmps-(SELECT AVG(tmps) FROM i_partitions_train_win_samples_1))*
#        (tmps-(SELECT AVG(tmps) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(tmps)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(hrs) AS avg,
#        SUM((hrs-(SELECT AVG(hrs) FROM i_partitions_train_win_samples_1))*
#        (hrs-(SELECT AVG(hrs) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(hrs)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(sbps) AS avg,
#        SUM((sbps-(SELECT AVG(sbps) FROM i_partitions_train_win_samples_1))*
#        (sbps-(SELECT AVG(sbps) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(sbps)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(rrs) AS avg,
#        SUM((rrs-(SELECT AVG(rrs) FROM i_partitions_train_win_samples_1))*
#        (rrs-(SELECT AVG(rrs) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(rrs)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(dbps) AS avg,
#        SUM((dbps-(SELECT AVG(dbps) FROM i_partitions_train_win_samples_1))*
#        (dbps-(SELECT AVG(dbps) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(dbps)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(sats) AS avg,
#        SUM((sats-(SELECT AVG(sats) FROM i_partitions_train_win_samples_1))*
#        (sats-(SELECT AVG(sats) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(sats)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT AVG(wgts) AS avg,
#        SUM((wgts-(SELECT AVG(wgts) FROM i_partitions_train_win_samples_1))*
#        (wgts-(SELECT AVG(wgts) FROM i_partitions_train_win_samples_1)))
#        /(COUNT(wgts)-1) AS var
# FROM i_partitions_train_win_samples_1
# ;
#
# SELECT COUNT(*) FROM i_partitions_train_win_samples_2;
#
# SELECT dx, COUNT(*) AS n
# FROM i_partitions_train_win_samples_2
# GROUP BY dx
# ORDER BY n DESC
# ;
#
#
# SELECT COUNT(*) FROM i_partitions_train_win_samples_3;
#
# SELECT outcome, COUNT(*) AS n
# FROM i_partitions_train_win_samples_3
# GROUP BY outcome
# ORDER BY n DESC
# ;

# %%
h.set_relcal()
# Out:
# SELECT min(i_st) AS i_st, max(i_et) AS i_et
# FROM (
#     SELECT i_id, i_st, i_et
# 	FROM samples_0
# 	UNION
# 		SELECT i_id, i_st, i_et
# 	FROM samples_1
# 	UNION
# 		SELECT i_id, i_st, i_et
# 	FROM samples_2
# 	UNION
# 		SELECT i_id, i_st, i_et
# 	FROM samples_3
#
# );
#
# INSERT  INTO i_relcal (i_id, i_st, i_et) VALUES (?, ?, ?);

# %%
h.fil_agg()
# Out:
# CREATE VIEW fil_characteristics_0 AS
#     SELECT i_id,
# 	CASE
# 	    WHEN 25.5177928478575>age THEN 25.0
# 	    WHEN age>64.58496404437307 THEN 65.0 ELSE age
# 	END AS age,
# 	CASE
# 	    WHEN sex IN ('M') THEN 1
# 	    ELSE 0
# 	END AS sex,
# 	CASE
# 	    WHEN eth IN ('e0', 'e1', 'e2', 'e3', 'e4', 'e5') THEN eth
# 	    ELSE '_OTHER_'
# 	END AS eth,
# 	CASE
# 	    WHEN bin_ldc IN ('A', 'B') THEN bin_ldc
# 	    ELSE '_OTHER_'
# 	END AS bin_ldc,
# 	CASE
# 	    WHEN job IN ('j000', 'j001', 'j002', 'j003', 'j004', 'j005', 'j006', 'j009', 'j007', 'j008', 'j012', 'j010', 'j011', 'j013', 'j015', 'j017', 'j014', 'j016', 'j020', 'j022', 'j018', 'j021', 'j023', 'j027', 'j019', 'j026', 'j032', 'j025', 'j033', 'j029', 'j039', 'j045', 'j031', 'j035', 'j037', 'j028', 'j043', 'j024', 'j036', 'j041', 'j038', 'j030', 'j034', 'j066', 'j042', 'j055', 'j051', 'j048', 'j062', 'j044', 'j098', 'j086', 'j079', 'j052', 'j047', 'j046', 'j064', 'j058', 'j040', 'j069', 'j053', 'j094', 'j075', 'j072', 'j060', 'j057', 'j054', 'j101', 'j076', 'j073', 'j063', 'j059', 'j056', 'j104', 'j096', 'j070', 'j050', 'j049', 'j143', 'j099', 'j093', 'j132', 'j116', 'j091', 'j088', 'j087', 'j085', 'j084', 'j083', 'j068', 'j065', 'j113', 'j095', 'j081', 'j078', 'j077', 'j071', 'j067', 'j061', 'j196', 'j161', 'j146', 'j123', 'j105', 'j127', 'j121', 'j092', 'j082', 'j074', 'j414', 'j253', 'j252', 'j216', 'j199', 'j173', 'j168', 'j166', 'j138', 'j117', 'j110', 'j107', 'j102', 'j100', 'j097', 'j090', 'j089', 'j285', 'j243', 'j222', 'j217', 'j178', 'j163', 'j162', 'j157', 'j153', 'j145', 'j137', 'j129', 'j119', 'j118', 'j114', 'j109', 'j244', 'j231', 'j225', 'j223', 'j220', 'j176', 'j174', 'j172', 'j170', 'j156', 'j155', 'j154', 'j152', 'j149', 'j141', 'j139', 'j133', 'j131', 'j112', 'j111', 'j080', 'j465', 'j305', 'j264', 'j254', 'j249', 'j248', 'j242', 'j221', 'j218', 'j204', 'j192', 'j191', 'j175', 'j164', 'j160', 'j150', 'j148', 'j147', 'j144', 'j142', 'j134', 'j128', 'j124', 'j122', 'j115', 'j106', 'j103', 'j553', 'j497', 'j490', 'j395', 'j382', 'j371', 'j362', 'j341', 'j333', 'j314', 'j312', 'j302', 'j298', 'j290', 'j289', 'j288', 'j281', 'j271', 'j247', 'j246', 'j240', 'j239', 'j228', 'j226', 'j213', 'j211', 'j208', 'j205', 'j203', 'j188', 'j183', 'j181', 'j180', 'j177', 'j171', 'j158', 'j140', 'j136', 'j130', 'j120', 'j966', 'j886', 'j824', 'j772', 'j686', 'j681', 'j651', 'j648', 'j618', 'j616', 'j612', 'j583', 'j529', 'j512', 'j510', 'j495', 'j479', 'j452', 'j443', 'j437', 'j429', 'j427', 'j402', 'j401', 'j399', 'j394', 'j365', 'j364', 'j340', 'j338', 'j336', 'j313', 'j308', 'j299', 'j295', 'j274', 'j272', 'j266', 'j251', 'j250', 'j241', 'j238', 'j236', 'j233', 'j197', 'j194', 'j190', 'j186', 'j182', 'j169', 'j135', 'j125', 'j108', 'j981', 'j948', 'j915', 'j883', 'j843', 'j800', 'j787', 'j779', 'j771', 'j764', 'j760', 'j742', 'j732', 'j731', 'j728', 'j721', 'j712', 'j690', 'j600', 'j593', 'j589', 'j571', 'j565', 'j545', 'j544', 'j527', 'j520', 'j516', 'j500', 'j492', 'j476', 'j474', 'j473', 'j462', 'j460', 'j459', 'j458', 'j454', 'j451', 'j450', 'j444', 'j439', 'j431', 'j430', 'j428', 'j422', 'j413', 'j410', 'j409', 'j391', 'j385', 'j384', 'j380', 'j379', 'j375', 'j372', 'j360', 'j357', 'j355', 'j347', 'j346', 'j345', 'j331', 'j329', 'j328', 'j323', 'j321', 'j318', 'j317', 'j309', 'j304', 'j287', 'j286', 'j284', 'j282', 'j270', 'j269', 'j263', 'j261', 'j258', 'j245', 'j232', 'j229', 'j210', 'j198', 'j195', 'j187', 'j185', 'j184', 'j165', 'j151', 'j995', 'j986', 'j971', 'j969', 'j963', 'j944', 'j940', 'j935', 'j929', 'j921', 'j913', 'j908', 'j893', 'j851', 'j825', 'j792', 'j766', 'j759', 'j744', 'j741', 'j729', 'j724', 'j718', 'j708', 'j671', 'j661', 'j659', 'j646', 'j641', 'j640', 'j639', 'j628', 'j627', 'j621', 'j615', 'j614', 'j613', 'j608', 'j596', 'j586', 'j576', 'j573', 'j556', 'j551', 'j541', 'j540', 'j536', 'j535', 'j526', 'j522', 'j515', 'j507', 'j503', 'j501', 'j487', 'j486', 'j483', 'j480', 'j472', 'j471', 'j469', 'j464', 'j463', 'j455', 'j449', 'j447', 'j446', 'j436', 'j435', 'j434', 'j425', 'j424', 'j423', 'j420', 'j417', 'j412', 'j411', 'j405', 'j398', 'j397', 'j393', 'j389', 'j387', 'j381', 'j376', 'j370', 'j367', 'j366', 'j363', 'j361', 'j353', 'j350', 'j339', 'j337', 'j332', 'j330', 'j327', 'j325', 'j316', 'j306', 'j303', 'j300', 'j293', 'j292', 'j291', 'j283', 'j279', 'j277', 'j276', 'j273', 'j262', 'j260', 'j256', 'j237', 'j234', 'j227', 'j224', 'j219', 'j215', 'j214', 'j209', 'j206', 'j202', 'j179' ...
# 	    ELSE '_OTHER_'
# 	END AS job
# 	FROM characteristics_0
#
# ;
#
# CREATE VIEW ohe_characteristics_0 AS
#     SELECT i_id,
# 	age,
# 	sex,
# 	CASE
# 	    WHEN eth IN ('e0') THEN 1
# 	    ELSE 0
# 	END AS eth_e0,
# 	CASE
# 	    WHEN eth IN ('e1') THEN 1
# 	    ELSE 0
# 	END AS eth_e1,
# 	CASE
# 	    WHEN eth IN ('e2') THEN 1
# 	    ELSE 0
# 	END AS eth_e2,
# 	CASE
# 	    WHEN eth IN ('e3') THEN 1
# 	    ELSE 0
# 	END AS eth_e3,
# 	CASE
# 	    WHEN eth IN ('e4') THEN 1
# 	    ELSE 0
# 	END AS eth_e4,
# 	CASE
# 	    WHEN eth IN ('e5') THEN 1
# 	    ELSE 0
# 	END AS eth_e5,
# 	CASE
# 	    WHEN eth IN ('_OTHER_') THEN 1
# 	    ELSE 0
# 	END AS eth__OTHER_,
# 	CASE
# 	    WHEN bin_ldc IN ('A') THEN 1
# 	    ELSE 0
# 	END AS bin_ldc_A,
# 	CASE
# 	    WHEN bin_ldc IN ('B') THEN 1
# 	    ELSE 0
# 	END AS bin_ldc_B,
# 	CASE
# 	    WHEN bin_ldc IN ('_OTHER_') THEN 1
# 	    ELSE 0
# 	END AS bin_ldc__OTHER_,
# 	job
# 	FROM fil_characteristics_0
#
# ;
#
# CREATE VIEW fil_samples_0 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	CASE
# 	    WHEN 110.22677016356627>SBP THEN 110.0
# 	    WHEN SBP>129.81405811588098 THEN 130.0 ELSE SBP
# 	END AS SBP,
# 	CASE
# 	    WHEN 70.20640670486999>DBP THEN 70.0
# 	    WHEN DBP>89.78999718137551 THEN 90.0 ELSE DBP
# 	END AS DBP,
# 	CASE
# 	    WHEN type IN ('c0', 'c1', 'c2', 'c3', 'c4') THEN type
# 	    ELSE '_OTHER_'
# 	END AS type
# 	FROM win_samples_0
#
# ;
#
# CREATE VIEW ohe_samples_0 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	SBP,
# 	DBP,
# 	CASE
# 	    WHEN type IN ('c0') THEN 1
# 	    ELSE 0
# 	END AS type_c0,
# 	CASE
# 	    WHEN type IN ('c1') THEN 1
# 	    ELSE 0
# 	END AS type_c1,
# 	CASE
# 	    WHEN type IN ('c2') THEN 1
# 	    ELSE 0
# 	END AS type_c2,
# 	CASE
# 	    WHEN type IN ('c3') THEN 1
# 	    ELSE 0
# 	END AS type_c3,
# 	CASE
# 	    WHEN type IN ('c4') THEN 1
# 	    ELSE 0
# 	END AS type_c4,
# 	CASE
# 	    WHEN type IN ('_OTHER_') THEN 1
# 	    ELSE 0
# 	END AS type__OTHER_
# 	FROM fil_samples_0
#
# ;
#
# CREATE VIEW agg_samples_0 AS
#     SELECT
# 	ohe_samples_0.i_id AS i_id,
# 	i_relcal.i_st AS i_st,
# 	i_relcal.i_et AS i_et,
# 	AVG(SBP) AS avg_SBP,
# 	MIN(SBP) AS min_SBP,
# 	MAX(SBP) AS max_SBP,
# 	AVG(DBP) AS avg_DBP,
# 	MIN(DBP) AS min_DBP,
# 	MAX(DBP) AS max_DBP,
# 	AVG(type_c0) AS avg_type_c0,
# 	AVG(type_c1) AS avg_type_c1,
# 	AVG(type_c2) AS avg_type_c2,
# 	AVG(type_c3) AS avg_type_c3,
# 	AVG(type_c4) AS avg_type_c4,
# 	AVG(type__OTHER_) AS avg_type__OTHER_,
# 	COUNT() as count
# 	FROM ohe_samples_0, i_relcal
# 	WHERE NOT (i_relcal.i_et <= ohe_samples_0.i_st OR
# 	           i_relcal.i_st >= ohe_samples_0.i_et)
# 	GROUP BY ohe_samples_0.i_id, i_relcal.i_st
# ;
#
# CREATE VIEW fil_samples_1 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	CASE
# 	    WHEN 35.775966168940315>tmps THEN 35.0
# 	    WHEN tmps>37.5003246723675 THEN 38.0 ELSE tmps
# 	END AS tmps,
# 	CASE
# 	    WHEN 55.15364765528836>hrs THEN 55.0
# 	    WHEN hrs>74.82086649974192 THEN 75.0 ELSE hrs
# 	END AS hrs,
# 	CASE
# 	    WHEN 110.18188478778953>sbps THEN 110.0
# 	    WHEN sbps>129.78822066941288 THEN 130.0 ELSE sbps
# 	END AS sbps,
# 	CASE
# 	    WHEN 25.12386331677365>rrs THEN 25.0
# 	    WHEN rrs>34.904796919086664 THEN 35.0 ELSE rrs
# 	END AS rrs,
# 	CASE
# 	    WHEN 70.16542120452284>dbps THEN 70.0
# 	    WHEN dbps>89.8000989556639 THEN 90.0 ELSE dbps
# 	END AS dbps,
# 	CASE
# 	    WHEN 94.65807554563456>sats THEN 94.0
# 	    WHEN sats>100.32727229527852 THEN 101.0 ELSE sats
# 	END AS sats,
# 	CASE
# 	    WHEN 106.11570369396858>wgts THEN 106.0
# 	    WHEN wgts>203.86693958388875 THEN 204.0 ELSE wgts
# 	END AS wgts
# 	FROM win_samples_1
#
# ;
#
# CREATE VIEW ohe_samples_1 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	tmps,
# 	hrs,
# 	sbps,
# 	rrs,
# 	dbps,
# 	sats,
# 	wgts
# 	FROM fil_samples_1
#
# ;
#
# CREATE VIEW agg_samples_1 AS
#     SELECT
# 	ohe_samples_1.i_id AS i_id,
# 	i_relcal.i_st AS i_st,
# 	i_relcal.i_et AS i_et,
# 	AVG(tmps) AS avg_tmps,
# 	MIN(tmps) AS min_tmps,
# 	MAX(tmps) AS max_tmps,
# 	AVG(hrs) AS avg_hrs,
# 	MIN(hrs) AS min_hrs,
# 	MAX(hrs) AS max_hrs,
# 	AVG(sbps) AS avg_sbps,
# 	MIN(sbps) AS min_sbps,
# 	MAX(sbps) AS max_sbps,
# 	AVG(rrs) AS avg_rrs,
# 	MIN(rrs) AS min_rrs,
# 	MAX(rrs) AS max_rrs,
# 	AVG(dbps) AS avg_dbps,
# 	MIN(dbps) AS min_dbps,
# 	MAX(dbps) AS max_dbps,
# 	AVG(sats) AS avg_sats,
# 	MIN(sats) AS min_sats,
# 	MAX(sats) AS max_sats,
# 	AVG(wgts) AS avg_wgts,
# 	MIN(wgts) AS min_wgts,
# 	MAX(wgts) AS max_wgts,
# 	COUNT() as count
# 	FROM ohe_samples_1, i_relcal
# 	WHERE NOT (i_relcal.i_et <= ohe_samples_1.i_st OR
# 	           i_relcal.i_st >= ohe_samples_1.i_et)
# 	GROUP BY ohe_samples_1.i_id, i_relcal.i_st
# ;
#
# CREATE VIEW fil_samples_2 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	CASE
# 	    WHEN dx IN ('d0000', 'd0001', 'd0002', 'd0003', 'd0004', 'd0005', 'd0006', 'd0007', 'd0008', 'd0009', 'd0010', 'd0011', 'd0012', 'd0013', 'd0014', 'd0015', 'd0017', 'd0016', 'd0018', 'd0019', 'd0023', 'd0020', 'd0022', 'd0021', 'd0024', 'd0026', 'd0025', 'd0027', 'd0028', 'd0031', 'd0030', 'd0034', 'd0029', 'd0035', 'd0033', 'd0037', 'd0032', 'd0036', 'd0040', 'd0042', 'd0039', 'd0043', 'd0041', 'd0038', 'd0044', 'd0046', 'd0045', 'd0047', 'd0051', 'd0049', 'd0050', 'd0048', 'd0055', 'd0057', 'd0052', 'd0060', 'd0053', 'd0058', 'd0062', 'd0059', 'd0056', 'd0054', 'd0063', 'd0066', 'd0061', 'd0072', 'd0069', 'd0064', 'd0068', 'd0080', 'd0071', 'd0078', 'd0065', 'd0070', 'd0075', 'd0073', 'd0067', 'd0087', 'd0079', 'd0076', 'd0082', 'd0084', 'd0074', 'd0081', 'd0077', 'd0089', 'd0097', 'd0088', 'd0092', 'd0086', 'd0083', 'd0101', 'd0085', 'd0090', 'd0091', 'd0104', 'd0093', 'd0103', 'd0095', 'd0108', 'd0094', 'd0115', 'd0113', 'd0109', 'd0096', 'd0110', 'd0098', 'd0124', 'd0102', 'd0099', 'd0116', 'd0111', 'd0107', 'd0106', 'd0100', 'd0118', 'd0126', 'd0114', 'd0119', 'd0105', 'd0137', 'd0117', 'd0139', 'd0134', 'd0125', 'd0129', 'd0132', 'd0121', 'd0135', 'd0123', 'd0140', 'd0133', 'd0145', 'd0128', 'd0136', 'd0120', 'd0151', 'd0141', 'd0127', 'd0138', 'd0112', 'd0130', 'd0168', 'd0146', 'd0175', 'd0169', 'd0131', 'd0148', 'd0155', 'd0122', 'd0147', 'd0164', 'd0143', 'd0158', 'd0144', 'd0173', 'd0184', 'd0177', 'd0156', 'd0142', 'd0152', 'd0161', 'd0154', 'd0153', 'd0149', 'd0150', 'd0187', 'd0159', 'd0211', 'd0188', 'd0160', 'd0189', 'd0163', 'd0157', 'd0182', 'd0185', 'd0176', 'd0192', 'd0196', 'd0180', 'd0166', 'd0219', 'd0213', 'd0207', 'd0200', 'd0199', 'd0186', 'd0174', 'd0172', 'd0214', 'd0183', 'd0171', 'd0170', 'd0222', 'd0235', 'd0195', 'd0181', 'd0165', 'd0162', 'd0179', 'd0167', 'd0228', 'd0190', 'd0198', 'd0193', 'd0220', 'd0212', 'd0210', 'd0201', 'd0191', 'd0223', 'd0218', 'd0225', 'd0224', 'd0204', 'd0202', 'd0178', 'd0263', 'd0259', 'd0206', 'd0205', 'd0239', 'd0203', 'd0194', 'd0231', 'd0227', 'd0215', 'd0262', 'd0252', 'd0229', 'd0226', 'd0197', 'd0270', 'd0249', 'd0209', 'd0266', 'd0230', 'd0245', 'd0221', 'd0256', 'd0255', 'd0254', 'd0217', 'd0326', 'd0240', 'd0318', 'd0316', 'd0307', 'd0250', 'd0247', 'd0216', 'd0309', 'd0251', 'd0243', 'd0242', 'd0269', 'd0253', 'd0248', 'd0241', 'd0238', 'd0234', 'd0302', 'd0283', 'd0265', 'd0257', 'd0244', 'd0317', 'd0312', 'd0271', 'd0264', 'd0236', 'd0208', 'd0333', 'd0324', 'd0291', 'd0261', 'd0232', 'd0268', 'd0258', 'd0327', 'd0306', 'd0282', 'd0237', 'd0356', 'd0321', 'd0296', 'd0284', 'd0233', 'd0290', 'd0280', 'd0348', 'd0346', 'd0295', 'd0279', 'd0366', 'd0351', 'd0335', 'd0331', 'd0310', 'd0305', 'd0294', 'd0292', 'd0288', 'd0274', 'd0272', 'd0345', 'd0320', 'd0297', 'd0289', 'd0287', 'd0275', 'd0337', 'd0330', 'd0273', 'd0260', 'd0246', 'd0418', 'd0377', 'd0367', 'd0304', 'd0300', 'd0375', 'd0322', 'd0314', 'd0293', 'd0278', 'd0376', 'd0374', 'd0372', 'd0350', 'd0329', 'd0319', 'd0285', 'd0276', 'd0411', 'd0402', 'd0391', 'd0365', 'd0334', 'd0313', 'd0281', 'd0420', 'd0404', 'd0383', 'd0362', 'd0359', 'd0354', 'd0342', 'd0340', 'd0328', 'd0487', 'd0441', 'd0433', 'd0421', 'd0385', 'd0373', 'd0470', 'd0444', 'd0436', 'd0426', 'd0396', 'd0382', 'd0357', 'd0336', 'd0303', 'd0449', 'd0405', 'd0380', 'd0343', 'd0338', 'd0299', 'd0298', 'd0514', 'd0472', 'd0447', 'd0422', 'd0325', 'd0323', 'd0453', 'd0452', 'd0419', 'd0403', 'd0386', 'd0371', 'd0361', 'd0355', 'd0349', 'd0267', 'd0440', 'd0428', 'd0401', 'd0395', 'd0389', 'd0347', 'd0344', 'd0301', 'd0277', 'd0499', 'd0493', 'd0484', 'd0468', 'd0466', 'd0457', 'd0448', 'd0438', 'd0425', 'd0412', 'd0392', 'd0364', 'd0360', 'd0352', 'd0315', 'd0286', 'd0553', 'd0504', 'd0490', 'd0489', 'd0465', 'd0461', 'd0423', 'd0410', 'd0408', 'd0400', 'd0397', 'd0393', 'd0379', 'd0369', 'd0363', 'd0341', 'd0563', 'd0454', 'd0388', 'd0568', 'd0432', 'd0414', 'd0368', 'd0358', 'd0339', 'd0517', 'd0501', 'd0474', 'd0463', 'd045 ...
# 	    ELSE '_OTHER_'
# 	END AS dx
# 	FROM win_samples_2
#
# ;
#
# CREATE VIEW ohe_samples_2 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	dx
# 	FROM fil_samples_2
#
# ;
#
# CREATE VIEW agg_samples_2 AS
#     SELECT
# 	ohe_samples_2.i_id AS i_id,
# 	i_relcal.i_st AS i_st,
# 	i_relcal.i_et AS i_et,
# 	group_concat(dx) AS concat_dx,
# 	COUNT() as count
# 	FROM ohe_samples_2, i_relcal
# 	WHERE NOT (i_relcal.i_et <= ohe_samples_2.i_st OR
# 	           i_relcal.i_st >= ohe_samples_2.i_et)
# 	GROUP BY ohe_samples_2.i_id, i_relcal.i_st
# ;
#
# CREATE VIEW fil_samples_3 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	CASE
# 	    WHEN outcome IN ('1.0') THEN 1
# 	    ELSE 0
# 	END AS outcome
# 	FROM win_samples_3
#
# ;
#
# CREATE VIEW ohe_samples_3 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	outcome
# 	FROM fil_samples_3
#
# ;
#
# CREATE VIEW agg_samples_3 AS
#     SELECT
# 	ohe_samples_3.i_id AS i_id,
# 	i_relcal.i_st AS i_st,
# 	i_relcal.i_et AS i_et,
# 	AVG(outcome) AS avg_outcome,
# 	COUNT() as count
# 	FROM ohe_samples_3, i_relcal
# 	WHERE NOT (i_relcal.i_et <= ohe_samples_3.i_st OR
# 	           i_relcal.i_st >= ohe_samples_3.i_et)
# 	GROUP BY ohe_samples_3.i_id, i_relcal.i_st
# ;

# %%
h.create_partition_views_prior_to_normalization()
# Out:
# SELECT DISTINCT(partition) FROM i_partitions;
#
# partitions: dev,train,test
#
# CREATE VIEW i_partitions_dev_ohe_characteristics_0 AS
#     SELECT * FROM ohe_characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_ohe_characteristics_0 AS
#     SELECT * FROM ohe_characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_ohe_characteristics_0 AS
#     SELECT * FROM ohe_characteristics_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_agg_samples_0 AS
#     SELECT * FROM agg_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_agg_samples_0 AS
#     SELECT * FROM agg_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_agg_samples_0 AS
#     SELECT * FROM agg_samples_0
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_agg_samples_1 AS
#     SELECT * FROM agg_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_agg_samples_1 AS
#     SELECT * FROM agg_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_agg_samples_1 AS
#     SELECT * FROM agg_samples_1
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_agg_samples_2 AS
#     SELECT * FROM agg_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_agg_samples_2 AS
#     SELECT * FROM agg_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_agg_samples_2 AS
#     SELECT * FROM agg_samples_2
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_dev_agg_samples_3 AS
#     SELECT * FROM agg_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='dev'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_train_agg_samples_3 AS
#     SELECT * FROM agg_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='train'
# 	)
#
# ;
#
# CREATE VIEW i_partitions_test_agg_samples_3 AS
#     SELECT * FROM agg_samples_3
# 	WHERE i_id IN (
# 	    SELECT i_id
# 	    FROM i_partitions
# 	    WHERE partition='test'
# 	)
#
# ;

# %%
# %time h.fit_normalization(partition='train')
# Out:
# SELECT AVG(age),
# COUNT(age)
# FROM i_partitions_train_ohe_characteristics_0;
#
# SELECT SUM((age-(45.06754385964912))*(age-(45.06754385964912)))/(7980-1)
# FROM i_partitions_train_ohe_characteristics_0;
#
# SELECT AVG(avg_SBP),
# COUNT(avg_SBP),
# AVG(min_SBP),
# COUNT(min_SBP),
# AVG(max_SBP),
# COUNT(max_SBP),
# AVG(avg_DBP),
# COUNT(avg_DBP),
# AVG(min_DBP),
# COUNT(min_DBP),
# AVG(max_DBP),
# COUNT(max_DBP),
# AVG(count),
# COUNT(count)
# FROM i_partitions_train_agg_samples_0;
#
# SELECT SUM((avg_SBP-(120.02261904244791))*(avg_SBP-(120.02261904244791)))/(103487-1),
# SUM((min_SBP-(118.74816564069697))*(min_SBP-(118.74816564069697)))/(103487-1),
# SUM((max_SBP-(121.29622532078133))*(max_SBP-(121.29622532078133)))/(103487-1),
# SUM((avg_DBP-(80.00235053576667))*(avg_DBP-(80.00235053576667)))/(103487-1),
# SUM((min_DBP-(78.73336831408065))*(min_DBP-(78.73336831408065)))/(103487-1),
# SUM((max_DBP-(81.27189394965903))*(max_DBP-(81.27189394965903)))/(103487-1),
# SUM((count-(1.5422226946379738))*(count-(1.5422226946379738)))/(103487-1)
# FROM i_partitions_train_agg_samples_0;
#
# SELECT AVG(avg_tmps),
# COUNT(avg_tmps),
# AVG(min_tmps),
# COUNT(min_tmps),
# AVG(max_tmps),
# COUNT(max_tmps),
# AVG(avg_hrs),
# COUNT(avg_hrs),
# AVG(min_hrs),
# COUNT(min_hrs),
# AVG(max_hrs),
# COUNT(max_hrs),
# AVG(avg_sbps),
# COUNT(avg_sbps),
# AVG(min_sbps),
# COUNT(min_sbps),
# AVG(max_sbps),
# COUNT(max_sbps),
# AVG(avg_rrs),
# COUNT(avg_rrs),
# AVG(min_rrs),
# COUNT(min_rrs),
# AVG(max_rrs),
# COUNT(max_rrs),
# AVG(avg_dbps),
# COUNT(avg_dbps),
# AVG(min_dbps),
# COUNT(min_dbps),
# AVG(max_dbps),
# COUNT(max_dbps),
# AVG(avg_sats),
# COUNT(avg_sats),
# AVG(min_sats),
# COUNT(min_sats),
# AVG(max_sats),
# COUNT(max_sats),
# AVG(avg_wgts),
# COUNT(avg_wgts),
# AVG(min_wgts),
# COUNT(min_wgts),
# AVG(max_wgts),
# COUNT(max_wgts),
# AVG(count),
# COUNT(count)
# FROM i_partitions_train_agg_samples_1;
#
# SELECT SUM((avg_tmps-(36.63029191182955))*(avg_tmps-(36.63029191182955)))/(103612-1),
# SUM((min_tmps-(36.5033467661712))*(min_tmps-(36.5033467661712)))/(103612-1),
# SUM((max_tmps-(36.755849200387956))*(max_tmps-(36.755849200387956)))/(103612-1),
# SUM((avg_hrs-(64.99147369835829))*(avg_hrs-(64.99147369835829)))/(103612-1),
# SUM((min_hrs-(63.71433754445818))*(min_hrs-(63.71433754445818)))/(103612-1),
# SUM((max_hrs-(66.26542206771316))*(max_hrs-(66.26542206771316)))/(103612-1),
# SUM((avg_sbps-(119.98138213806547))*(avg_sbps-(119.98138213806547)))/(103612-1),
# SUM((min_sbps-(118.70983387437336))*(min_sbps-(118.70983387437336)))/(103612-1),
# SUM((max_sbps-(121.25505320188881))*(max_sbps-(121.25505320188881)))/(103612-1),
# SUM((avg_rrs-(30.009667231664395))*(avg_rrs-(30.009667231664395)))/(103612-1),
# SUM((min_rrs-(29.376794430078757))*(min_rrs-(29.376794430078757)))/(103612-1),
# SUM((max_rrs-(30.642725874447674))*(max_rrs-(30.642725874447674)))/(103612-1),
# SUM((avg_dbps-(79.99337518170653))*(avg_dbps-(79.99337518170653)))/(103612-1),
# SUM((min_dbps-(78.72190007856342))*(min_dbps-(78.72190007856342)))/(103612-1),
# SUM((max_dbps-(81.26666247298078))*(max_dbps-(81.26666247298078)))/(103612-1),
# SUM((avg_sats-(97.49256877102637))*(avg_sats-(97.49256877102637)))/(103612-1),
# SUM((min_sats-(97.10360527104886))*(min_sats-(97.10360527104886)))/(103612-1),
# SUM((max_sats-(97.88190232739721))*(max_sats-(97.88190232739721)))/(103612-1),
# SUM((avg_wgts-(154.97738556673798))*(avg_wgts-(154.97738556673798)))/(103612-1),
# SUM((min_wgts-(148.63386068231534))*(min_wgts-(148.63386068231534)))/(103612-1),
# SUM((max_wgts-(161.3343233126349))*(max_wgts-(161.3343233126349)))/(103612-1),
# SUM((count-(1.5403621202177353))*(count-(1.5403621202177353)))/(103612-1)
# FROM i_partitions_train_agg_samples_1;
#
# SELECT AVG(count),
# COUNT(count)
# FROM i_partitions_train_agg_samples_2;
#
# SELECT SUM((count-(1.5401986045569034))*(count-(1.5401986045569034)))/(103623-1)
# FROM i_partitions_train_agg_samples_2;
#
# SELECT AVG(count),
# COUNT(count)
# FROM i_partitions_train_agg_samples_3;
#
# SELECT SUM((count-(1.0))*(count-(1.0)))/(91966-1)
# FROM i_partitions_train_agg_samples_3;
#
# CPU times: user 26 s, sys: 356 ms, total: 26.4 s
# Wall time: 26.5 s

# %%
# %time h.fit_normalization(partition='train', via_sql_qds=False)
# Out:
# SELECT age
# FROM i_partitions_train_ohe_characteristics_0
# ;
#
# SELECT avg_SBP, min_SBP, max_SBP, avg_DBP, min_DBP, max_DBP, count
# FROM i_partitions_train_agg_samples_0
# ;
#
# SELECT avg_tmps, min_tmps, max_tmps, avg_hrs, min_hrs, max_hrs, avg_sbps, min_sbps, max_sbps, avg_rrs, min_rrs, max_rrs, avg_dbps, min_dbps, max_dbps, avg_sats, min_sats, max_sats, avg_wgts, min_wgts, max_wgts, count
# FROM i_partitions_train_agg_samples_1
# ;
#
# SELECT count
# FROM i_partitions_train_agg_samples_2
# ;
#
# SELECT count
# FROM i_partitions_train_agg_samples_3
# ;
#
# CPU times: user 11.8 s, sys: 102 ms, total: 11.9 s
# Wall time: 12 s

# %%
h.normalize()
# Out:
# CREATE VIEW nrm_characteristics_0 AS
#     SELECT i_id,
# 	(age-46.0)/0.0 as age,
# 	sex,
# 	eth_e0,
# 	eth_e1,
# 	eth_e2,
# 	eth_e3,
# 	eth_e4,
# 	eth_e5,
# 	eth__OTHER_,
# 	bin_ldc_A,
# 	bin_ldc_B,
# 	bin_ldc__OTHER_,
# 	job
# 	FROM ohe_characteristics_0
#
# ;
#
# CREATE VIEW nrm_samples_0 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	(avg_SBP-80.36326989794998)/39.073828096734815 as avg_SBP,
# 	(min_SBP-85.38540290606761)/38.96663566136587 as min_SBP,
# 	(max_SBP-86.57065049041161)/37.49497050877817 as max_SBP,
# 	(avg_DBP-87.61502284977423)/39.288222925295074 as avg_DBP,
# 	(min_DBP-84.50788380986674)/40.6961527645471 as min_DBP,
# 	(max_DBP-86.75697880205409)/38.53049598124075 as max_DBP,
# 	avg_type_c0,
# 	avg_type_c1,
# 	avg_type_c2,
# 	avg_type_c3,
# 	avg_type_c4,
# 	avg_type__OTHER_,
# 	(count-88.33059642819819)/39.095763700612466 as count
# 	FROM agg_samples_0
#
# ;
#
# CREATE VIEW nrm_samples_1 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	(avg_tmps-79.84123834696194)/45.46869372541694 as avg_tmps,
# 	(min_tmps-81.94450523104504)/47.248942842210994 as min_tmps,
# 	(max_tmps-81.51481329368947)/50.339796707311415 as max_tmps,
# 	(avg_hrs-81.87276616019136)/46.954069631916575 as avg_hrs,
# 	(min_hrs-85.49147897656181)/56.198360477890894 as min_hrs,
# 	(max_hrs-83.23350700982685)/50.67013775346254 as max_hrs,
# 	(avg_sbps-79.77101318578019)/44.39558683049209 as avg_sbps,
# 	(min_sbps-78.1770900510076)/42.60248368368082 as min_sbps,
# 	(max_sbps-79.51775447792687)/44.16135808986098 as max_sbps,
# 	(avg_rrs-79.9948798748668)/45.36356397435974 as avg_rrs,
# 	(min_rrs-75.41351851460377)/34.66478304930887 as min_rrs,
# 	(max_rrs-72.2322282723621)/34.653108302977934 as max_rrs,
# 	(avg_dbps-76.74469531159194)/40.6206605234218 as avg_dbps,
# 	(min_dbps-78.6968390092271)/43.378009617422244 as min_dbps,
# 	(max_dbps-77.53967749480742)/39.76928705941488 as max_dbps,
# 	(avg_sats-80.1965352597401)/45.10173389334552 as avg_sats,
# 	(min_sats-83.1528673952766)/48.84946421835593 as min_sats,
# 	(max_sats-76.59188546385023)/38.8189675226376 as max_sats,
# 	(avg_wgts-76.44179432856613)/38.748088229121905 as avg_wgts,
# 	(min_wgts-81.05580178088772)/47.21202801448896 as min_wgts,
# 	(max_wgts-79.61535095695125)/46.040100287757255 as max_wgts,
# 	(count-75.07278235425643)/35.14962744388877 as count
# 	FROM agg_samples_1
#
# ;
#
# CREATE VIEW nrm_samples_2 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	concat_dx,
# 	(count-1.0)/0.0 as count
# 	FROM agg_samples_2
#
# ;
#
# CREATE VIEW nrm_samples_3 AS
#     SELECT i_id,
# 	i_st,
# 	i_et,
# 	avg_outcome,
# 	(count-1.0)/0.0 as count
# 	FROM agg_samples_3
#
# ;

# %%
h.execute("PRAGMA table_info(fil_characteristics_0);", size=10)
# Out:
# PRAGMA table_info(fil_characteristics_0);
# (0, 'i_id', 'TEXT', 0, None, 0)
# (1, 'age', '', 0, None, 0)
# (2, 'sex', '', 0, None, 0)
# (3, 'eth', '', 0, None, 0)
# (4, 'bin_ldc', '', 0, None, 0)
# (5, 'job', '', 0, None, 0)

# %%
#SELECT * FROM nrm_samples_3 WHERE i_id=='00000';
#SELECT * FROM agg_samples_3 WHERE i_id=='00000';
#SELECT * FROM ohe_samples_3 WHERE i_id=='00000';

# %%
#SELECT * FROM agg_samples_0 LIMIT 10;
#CREATE INDEX samples_0_index_type ON samples_0(type);
#SELECT * FROM i_partitions_dev_ohe_characteristics_0;
#["SBP", "DBP", "type"]

# %%
#h.interactive_session()
